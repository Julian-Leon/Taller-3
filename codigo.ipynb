# %%
import pandas as pd
data = pd.read_csv('real_estate_valuation_data_set.csv', index_col=0)
data.shape
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_42096\645160195.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# (414, 7)

# %%
data.head()
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#
#     Y house price of unit area
# No
# 1                         37.9
# 2                         42.2
# ...

# %% [markdown]
# X1: fecha de último movieminto
# X2: edad del inmueble
# X3: distancia a la estacion de metro mas cercana
# X4: Numero de tiendas de conveniencia
# X5: corresponde a la latitud en la cordenadas
# X6: Corresponde a la longitud en las coordenadas
# Y: Variable de respuesta expresando precio por metro cuadrado

# %%
data.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148971     17.712560
# std               0.281967     11.392485
# min            2012.667000      0.000000
# 25%            2012.917000      9.025000
# 50%            2013.167000     16.100000
# 75%            2013.417000     28.150000
# max            2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# ...

# %%
# %pip install geopy
from geopy.geocoders import Nominatim

coordenadas = (24.96903, 121.53336)

#Creao un geolocalizador
geolocalizador = Nominatim(user_agent="mi_aplicacion")

#Obtengo la dirección con las coordenadas
ubicacion = geolocalizador.reverse(coordenadas)

#Imprimo la dirección
print("Dirección encontrada:", ubicacion.address)
# Out:
# ...
#
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.3 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.3 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/40.3 kB 187.9 kB/s eta 0:00:01
#      -------------------------------------- 40.3/40.3 kB 192.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
# ...

# %% [markdown]
# Respecto al conteo de los datos no hay algo relevante para resaltar pues como tenemos esa tabla de datos de entrada se confirma que es un arreglo rectangular con todos los datos completos.
#
# Comportamiento individual de cada característica y variable de respuesta.
# -Transaction date: ?????????
# -House age: El promedio de las casas que se tienen en la base de datos es de unos 17 años, lo que indica que no son propiedades muy nuevas, pero como lo indica tambien el máximo una propiedad de 43 años tampoco es vieja. Los datos varían bastante respecto a la media en esta muestra con una desvest de 11,39 años.
# -Distance to the nearest MRT station: Para las propiedades en cuestion la media de distancia hasta el metro es bastante significativa, podría dar indicios que se ubican en zonas lejanas del centro o incluso zonas rurales. Igualmente los datos distan bastante de la media y esto tambien muestra que es un rango bastante amplio en el oscilan las distancias.
# -Número de tiendas de conveniencia: Esta característica bastante importante para la valuacion tiene en promedio una buena medida, con 4 tiendas de conveniencia en su entorno de media y una desviación de 3 aproximadamente. Como hay propiedades en la muestra que no tienen ni una de estas tiendas cerca tambien hay unas que tienen una ubicacion privilegiada contando con unas 10 tiendas.
# -Latitud y Longitud:
